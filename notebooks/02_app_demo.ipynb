# %%
import sys
import os

# 1. Add the project root to Python's path so it can find 'src'
# (This is needed because notebooks are often inside a subfolder)
sys.path.append(os.path.abspath('..'))

# 2. Import your new class
from src.rag_engine import FMCSAAssistant

# 3. Initialize the Bot
bot = FMCSAAssistant(db_path="../data/chroma_db")

# 4. Ask a question
response = bot.ask("What are the requirements for a driver's daily log?")

print("\n🤖 ANSWER:")
print(response["answer"])
print("\n📚 SOURCES:")
for s in response["sources"]:
    print(f"- {s}")
